# %% [markdown]
# # Covid19 Data Analysis Notebook
# ---------------------------------------

# %% [markdown]
# ## AIM: THIS MODEL SHOWS HOW COVID EFFECT OUR DAILY ROUTINE

# %% [markdown]
# ### Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
data_corona = pd.read_csv("covid19_Confirmed_dataset.csv")
data_corona.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
data_corona.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Deleting the useless columns

# %%
data_corona.drop(["Lat","Long"],axis=1)
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
# ...

# %%
data_corona.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ### Aggregating the rows by the country

# %%
data = data_corona.groupby("Country/Region").sum()

# %%
data.head()
# Out:
#                     Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan     33.0000  65.0000        0        0        0        0        0
# Albania         41.1533  20.1683        0        0        0        0        0
# Algeria         28.0339   1.6596        0        0        0        0        0
# Andorra         42.5063   1.5218        0        0        0        0        0
# Angola         -11.2027  17.8739        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
data.shape
# Out:
# (187, 102)

# %% [markdown]
# ### Visualizing data related to a country

# %%
data.loc["India"].plot()
data.loc["Italy"].plot()
data.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
#  describing the spread of the virus in a country.

# %%
data.loc['China'][:3].plot()

# %%
data.loc['Italy'].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
data.loc["China"].diff().plot()

# %% [markdown]
# ### finding maxmimum infection rate for China

# %%
data.loc["China"].diff().max()
# Out:
# 15136.0

# %%
data.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
data.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### finding maximum infection rate for all of the countries.

# %%
countries = list(data.index)
max_inf_rate = []

for c in countries:
    max_inf_rate.append(data.loc[c].diff().max())

# %%
data["max_inf_rate"] = max_inf_rate
data.head()
# Out:
#                     Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan     33.0000  65.0000        0        0        0        0        0
# Albania         41.1533  20.1683        0        0        0        0        0
# Algeria         28.0339   1.6596        0        0        0        0        0
# Andorra         42.5063   1.5218        0        0        0        0        0
# Angola         -11.2027  17.8739        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ### creating a new dataframe with only needed column

# %%
corona_analysis = pd.DataFrame(data["max_inf_rate"])

# %%
corona_analysis.head()
# Out:
#                 max_inf_rate
# Country/Region
# Afghanistan         232.0000
# Albania              34.0000
# Algeria             199.0000
# Andorra              43.0000
# Angola               29.0766

# %% [markdown]
# # The WorldHappinessReport

# %% [markdown]
# ### importing the dataset

# %%
data_happiness = pd.read_csv("worldwide_happiness_report.csv")
data_happiness.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
data_happiness.shape
# Out:
# (156, 9)

# %% [markdown]
# ### let's drop the useless columns

# %%
useless_columns = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
data_happiness.drop(useless_columns,axis = 1, inplace = True )
data_happiness.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### changing the indices of the dataframe

# %%
data_happiness.set_index("Country or region", inplace = True)
data_happiness.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### joining two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
data_corona.shape
# Out:
# (266, 104)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
data_happiness.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
data_happiness.shape
# Out:
# (156, 4)

# %%
final_data = corona_analysis.join(data_happiness)

# %%
final_data.head()
# Out:
#                 max_inf_rate  GDP per capita  Social support  \
# Country/Region
# Afghanistan         232.0000           0.350           0.517
# Albania              34.0000           0.947           0.848
# Algeria             199.0000           1.002           1.160
# Andorra              43.0000             NaN             NaN
# Angola               29.0766             NaN             NaN
#
#                 Healthy life expectancy  Freedom to make life choices
# Country/Region
# Afghanistan                       0.361                         0.000
# Albania                           0.874                         0.383
# Algeria                           0.785                         0.086
# Andorra                             NaN                           NaN
# Angola                              NaN                           NaN

# %% [markdown]
# ### correlation matrix

# %%
final_data.corr()
# Out:
#                               max_inf_rate  GDP per capita  Social support  \
# max_inf_rate                      1.000000        0.251203        0.194233
# GDP per capita                    0.251203        1.000000        0.759468
# Social support                    0.194233        0.759468        1.000000
# Healthy life expectancy           0.291478        0.863062        0.765286
# Freedom to make life choices      0.080998        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_inf_rate                                 0.291478
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_inf_rate                                      0.080998
# GDP per capita                                    0.394603
# ...

# %% [markdown]
# ### Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
final_data.head()
# Out:
#                 max_inf_rate  GDP per capita  Social support  \
# Country/Region
# Afghanistan         232.0000           0.350           0.517
# Albania              34.0000           0.947           0.848
# Algeria             199.0000           1.002           1.160
# Andorra              43.0000             NaN             NaN
# Angola               29.0766             NaN             NaN
#
#                 Healthy life expectancy  Freedom to make life choices
# Country/Region
# Afghanistan                       0.361                         0.000
# Albania                           0.874                         0.383
# Algeria                           0.785                         0.086
# Andorra                             NaN                           NaN
# Angola                              NaN                           NaN

# %%
final_data.columns
# Out:
# Index(['max_inf_rate', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices'],
#       dtype='object')

# %% [markdown]
# ### Plotting GDP vs maximum Infection rate

# %%
x1 = final_data["GDP per capita"]
y1 = final_data["max_inf_rate"]

# %%
sns.scatterplot(x1,y1)

# %%
sns.regplot(x1,np.log(y1))

# %% [markdown]
# ### Plotting Social support vs maximum Infection rate

# %%
x2 = final_data["Social support"]
y2 = final_data["max_inf_rate"]

# %%
sns.scatterplot(x2,y2)

# %%
sns.regplot(x2,np.log(y2))

# %% [markdown]
# ### Plotting Healthy life expectancy vs maximum Infection rate

# %%
x3 = final_data["Healthy life expectancy"]
y3 = final_data["max_inf_rate"]

# %%
sns.regplot(x3,np.log(y3))

# %% [markdown]
# ### Plotting Freedom to make life choices vs maximum Infection rate

# %%
x4 = final_data["Freedom to make life choices"]
y4 = final_data["max_inf_rate"]

# %%
sns.regplot(x4,np.log(y4))
